# %% [markdown]
# <h1 style="color: #cd36d5ff">Видос в YAML</h1>

# %%
# https://github.com/deepinvalue/video_annotations_to_yolo
"""
This script processes video annotations created using Label Studio, converting them into a
format suitable for the YOLO object detection model. The script has the capability to interpolate
bounding boxes for each intermediate frame based on key-frame annotations (as needed), and export
these labels (i.e., bounding box coordinates), along with the corresponding frames, into a
YOLO-compatible format. As it stands with Label Studio version 1.7.0, such functionality isn't
inherently available. Please note that video annotations should be exported in the JSON-MIN format.
"""

import argparse
import json
import csv
import copy
import cv2
from decimal import Decimal
from pathlib import Path
from tqdm import tqdm


def linear_interpolation(prev_seq, seq, label):
    # Define the start and end frame numbers
    a0 = prev_seq["frame"]
    a1 = seq["frame"]
    frames_info = dict()
    # Loop over all intermediate frames
    for frame in range(a0 + 1, a1):
        t = Decimal(frame - a0) / Decimal(a1 - a0)
        info = [label]
        # Interpolate bounding box dimensions for the current frame
        for b0, b1 in ((prev_seq[k], seq[k]) for k in ("x", "y", "width", "height")):
            info.append(str(b0 + t * (b1 - b0)))
        # Add interpolated information for the current frame to 'frames_info'
        frames_info[frame] = info
    return frames_info


def main(json_path, video_path, output_base):
    print("Parsing annotations from JSON")
    # Open the annotation file, which should be exported in "JSON-MIN" format
    with open(json_path) as f:
        video_labels = json.load(f, parse_float=Decimal)

    labels = set()
    for subject in video_labels[1]["box"]:
        labels.add(*subject["labels"])
    labels_dict = {k: i for i, k in enumerate(sorted(labels))}

    # Initialize dictionaries to store file information and frame timestamps
    files_dict = dict()
    frame_times = dict()

    # Loop over the subjects, i.e. football players in a match
    for subject in copy.deepcopy(video_labels[1]["box"]):
        # Get the subject labels (e.g. team-A, team-B, referee, ball)
        subject_labels = subject["labels"]

        # Map the label to its integer representation
        if len(subject_labels) == 1:
            label = labels_dict[subject_labels[0]]
        else:
            raise ValueError("Each subject must have exactly one label.")

        prev_seq = None

        # Process each sequence in the subject's timeline
        for seq in subject["sequence"]:
            frame = seq["frame"]

            # Adjust the x and y coordinates to be the center of the bounding box
            seq["x"] += seq["width"] / Decimal("2")
            seq["y"] += seq["height"] / Decimal("2")

            # Adjust the scale of bounding box dimensions
            for k in ("x", "y", "width", "height"):
                seq[k] /= Decimal("100")

            # If the current sequence is not adjacent to the previous sequence, perform linear interpolation
            if (
                (prev_seq is not None)
                and prev_seq["enabled"]
                and (frame - prev_seq["frame"] > 1)
            ):
                lines = linear_interpolation(prev_seq, seq, label)
            else:
                lines = dict()

            # Create the bounding box information line for the current frame
            lines[frame] = [label] + [
                str(seq[k]) for k in ("x", "y", "width", "height")
            ]

            # Add the bounding box information line to the corresponding frame in 'files_dict'
            for frame, info in lines.items():
                if frame in files_dict:
                    files_dict[frame].append(info)
                else:
                    files_dict[frame] = [info]

            # Store the timestamp for the current frame
            frame_times.update({frame: float(seq["time"])})

            prev_seq = seq

    # Sort the file information and frame timestamp dictionaries
    files_dict = dict(sorted(files_dict.items()))
    frame_times = dict(sorted(frame_times.items()))

    print("Exporting annotations in YOLO format")

    # Prepare YOLO directory structure
    output_path = Path(output_base)
    [
        (output_path / p).mkdir(parents=True, exist_ok=True)
        for p in ("images/", "labels/")
    ]

    # Write the YOLO classes
    with open(output_path / f"classes.txt", "w") as f:
        f.writelines(f"{line}\n" for line in labels_dict)

    max_frame = max(files_dict.keys())
    padding = len(str(max_frame))

    # Write the YOLO labels
    for frame, lines in files_dict.items():
        with open(
            output_path / "labels" / f"frame_{frame:0{padding}d}.txt", "w"
        ) as csvfile:
            csvwriter = csv.writer(csvfile, delimiter=" ")
            csvwriter.writerows(lines)

    # Extract the Frames
    if video_path is not None:
        vidcap = cv2.VideoCapture(video_path)
        print(f"Extracting frames")
        for frame in tqdm(files_dict):
            vidcap.set(cv2.CAP_PROP_POS_FRAMES, frame - 1)
            success, image = vidcap.read()
            if success:
                cv2.imwrite(
                    str(output_path / "images" / f"frame_{frame:0{padding}d}.jpg"),
                    image,
                )
            else:
                print(f"Unable to read frame {frame}. Quiting.")
                break

    print("Process finished successfully.")


if __name__ == "__main__":
    # parser = argparse.ArgumentParser(
    #     description="""This script processes video annotations exported from Label Studio
    #     in JSON-MIN format, converting them into a YOLO-compatible format. The script supports
    #     interpolation of bounding boxes for intermediate frames based on key-frame annotations
    #     and exports these labels along with corresponding frames (if a video path is provided).""",
    #     formatter_class=argparse.ArgumentDefaultsHelpFormatter
    # )
    # parser.add_argument("-j", "--json_path", required=True, help="Path to JSON annotations")
    # parser.add_argument("-v", "--video_path", default=None, help="Optional path to video file." \
    #                                                              " If provided, corresponding frames will be extracted.")
    # parser.add_argument("-o", "--output_base", default='output/', help="Path to output base directory")
    # args = parser.parse_args()

    json_path = r"D:\Datasets\EVE\mining_asteroid_01.json"
    video_path = r"D:\Datasets\EVE\mining_asteroid_01.mp4"
    output_base = r"D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01"
    main(json_path, video_path, output_base)
# Out:
# Parsing annotations from JSON
# Exporting annotations in YOLO format
# Extracting frames
# 100%|██████████| 8670/8670 [12:52<00:00, 11.22it/s]
# Process finished successfully.

# %% [markdown]
# <h1 style="color: #cd36d5ff">Создать валидирующие данные</h1>

# %%
import os
import math
import shutil

work_dir = (
    "D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01"
)
val_data_percent = 10
dirs = ["images", "labels"]

for dir in dirs:
    os.makedirs(os.path.join(work_dir, dir, "val"), exist_ok=True)
    os.makedirs(os.path.join(work_dir, dir, "train"), exist_ok=True)
    files = [
        f
        for f in os.listdir(os.path.join(work_dir, dir))
        if os.path.isfile(os.path.join(work_dir, dir, f))
    ]
    files.sort()

    # Копируем
    for i, file in enumerate(files):
        src = os.path.join(work_dir, dir, file)
        if i % val_data_percent == 0:
            dst = os.path.join(work_dir, dir, "val", file)
        else:
            dst = os.path.join(work_dir, dir, "train", file)
        shutil.move(src, dst)
        print(f"Скопирован: {file}")
# Out:
#   Cell In[5], line 17
#     i % val_data_percent == 0:
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h1 style="color: #cd36d5ff">Обрезать датасет</h1>

# %%
import os
import shutil

# Папка с исходными файлами
src_folder = "./data/output"

# Папка, куда копируем
dst_folder = "./data/output_only_5"
sub_folder = "val"

for dir in ["images", "labels"]:
    os.makedirs(
        os.path.join(dst_folder, dir, sub_folder), exist_ok=True
    )  # создаст папку, если её нет

# Список файлов

for dir in ["images", "labels"]:
    files = [
        f
        for f in os.listdir(os.path.join(src_folder, dir))
        if os.path.isfile(os.path.join(src_folder, dir, f))
    ]
    files.sort()

    # Берём каждый 5-й файл
    every_fifth = files[::52]

    # Копируем
    for f in every_fifth:
        src = os.path.join(src_folder, dir, f)
        dst = os.path.join(dst_folder, dir, sub_folder, f)
        shutil.copy2(src, dst)  # copy2 сохраняет дату и метаданные
        print(f"Скопирован: {f}")
# Out:
# Скопирован: frame_00001.jpg
# Скопирован: frame_00014.jpg
# Скопирован: frame_00027.jpg
# Скопирован: frame_00040.jpg
# Скопирован: frame_00053.jpg
# Скопирован: frame_00066.jpg
# Скопирован: frame_00079.jpg
# Скопирован: frame_00092.jpg
# Скопирован: frame_00105.jpg
# Скопирован: frame_00118.jpg
# Скопирован: frame_00131.jpg
# Скопирован: frame_00144.jpg
# Скопирован: frame_00157.jpg
# Скопирован: frame_00170.jpg
# Скопирован: frame_00183.jpg
# Скопирован: frame_00196.jpg
# Скопирован: frame_00209.jpg
# Скопирован: frame_00222.jpg
# Скопирован: frame_00235.jpg
# Скопирован: frame_00248.jpg
# Скопирован: frame_00261.jpg
# Скопирован: frame_01010.jpg
# Скопирован: frame_01023.jpg
# Скопирован: frame_01036.jpg
# Скопирован: frame_01049.jpg
# Скопирован: frame_01062.jpg
# Скопирован: frame_01075.jpg
# Скопирован: frame_01088.jpg
# Скопирован: frame_01101.jpg
# Скопирован: frame_01114.jpg
# Скопирован: frame_01127.jpg
# Скопирован: frame_01140.jpg
# Скопирован: frame_01153.jpg
# Скопирован: frame_01166.jpg
# Скопирован: frame_01179.jpg
# Скопирован: frame_01192.jpg
# Скопирован: frame_01205.jpg
# Скопирован: frame_01218.jpg
# Скопирован: frame_01231.jpg
# Скопирован: frame_01244.jpg
# Скопирован: frame_01257.jpg
# Скопирован: frame_01270.jpg
# Скопирован: frame_01283.jpg
# Скопирован: frame_01296.jpg
# Скопирован: frame_01309.jpg
# Скопирован: frame_01322.jpg
# Скопирован: frame_01335.jpg
# Скопирован: frame_01348.jpg
# Скопирован: frame_01361.jpg
# Скопирован: frame_01374.jpg
# Скопирован: frame_01387.jpg
# Скопирован: frame_01400.jpg
# Скопирован: frame_01413.jpg
# Скопирован: frame_01426.jpg
# Скопирован: frame_01439.jpg
# Скопирован: frame_01452.jpg
# Скопирован: frame_01465.jpg
# Скопирован: frame_01478.jpg
# Скопирован: frame_01491.jpg
# Скопирован: frame_01504.jpg
# Скопирован: frame_01517.jpg
# Скопирован: frame_01530.jpg
# Скопирован: frame_01543.jpg
# Скопирован: frame_01556.jpg
# Скопирован: frame_01569.jpg
# Скопирован: frame_01088.txt
# Скопирован: frame_01101.txt
# Скопирован: frame_01114.txt
# Скопирован: frame_01127.txt
# Скопирован: frame_01140.txt
# Скопирован: frame_01153.txt
# Скопирован: frame_01166.txt
# Скопирован: frame_01179.txt
# Скопирован: frame_01192.txt
# Скопирован: frame_01205.txt
# Скопирован: frame_01218.txt
# Скопирован: frame_01231.txt
# Скопирован: frame_01244.txt
# Скопирован: frame_01257.txt
# Скопирован: frame_01270.txt
# Скопирован: frame_01283.txt
# Скопирован: frame_01296.txt
# Скопирован: frame_01309.txt
# Скопирован: frame_01322.txt
# Скопирован: frame_01335.txt
# Скопирован: frame_01348.txt
# Скопирован: frame_01361.txt
# Скопирован: frame_01374.txt
# Скопирован: frame_01387.txt
# Скопирован: frame_01400.txt
# Скопирован: frame_01413.txt
# Скопирован: frame_01426.txt
# Скопирован: frame_01439.txt
# Скопирован: frame_01452.txt
# Скопирован: frame_01465.txt
# Скопирован: frame_01478.txt
# Скопирован: frame_01491.txt
# Скопирован: frame_01504.txt
# Скопирован: frame_01517.txt
# Скопирован: frame_01530.txt
# Скопирован: frame_01543.txt
# Скопирован: frame_01556.txt
# Скопирован: frame_01569.txt
# Скопирован: frame_01582.txt
# Скопирован: frame_01595.txt
# Скопирован: frame_01608.txt
# Скопирован: frame_01621.txt
# Скопирован: frame_01634.txt
# Скопирован: frame_01647.txt
# Скопирован: frame_01660.txt
# Скопирован: frame_01673.txt
# Скопирован: frame_01686.txt
# Скопирован: frame_01699.txt
# Скопирован: frame_01712.txt
# Скопирован: frame_01725.txt
# Скопирован: frame_01738.txt
# Скопирован: frame_01751.txt
# Скопирован: frame_01764.txt
# Скопирован: frame_01777.txt
# Скопирован: frame_01790.txt
# Скопирован: frame_01803.txt
# Скопирован: frame_01816.txt
# Скопирован: frame_01829.txt
# Скопирован: frame_01842.txt
# Скопирован: frame_01855.txt
# Скопирован: frame_01868.txt
# Скопирован: frame_01881.txt
# Скопирован: frame_01894.txt
# Скопирован: frame_01907.txt
# Скопирован: frame_01920.txt
# Скопирован: frame_01933.txt
# Скопирован: frame_01946.txt
# Скопирован: frame_01959.txt
# Скопирован: frame_01972.txt
# Скопирован: frame_01985.txt
# Скопирован: frame_01998.txt
# Скопирован: frame_02011.txt
# Скопирован: frame_02024.txt
# Скопирован: frame_02037.txt
# Скопирован: frame_02050.txt
# Скопирован: frame_02063.txt
# Скопирован: frame_02076.txt
# Скопирован: frame_02089.txt
# Скопирован: frame_02102.txt
# Скопирован: frame_02115.txt
# Скопирован: frame_02128.txt
# Скопирован: frame_02141.txt
# Скопирован: frame_02154.txt
# Скопирован: frame_02167.txt
# Скопирован: frame_02180.txt
# Скопирован: frame_02193.txt
# Скопирован: frame_02206.txt
# Скопирован: frame_02219.txt
# Скопирован: frame_02232.txt
# Скопирован: frame_02245.txt
# Скопирован: frame_02258.txt
# Скопирован: frame_02271.txt
# Скопирован: frame_02284.txt
# Скопирован: frame_02297.txt
# Скопирован: frame_02310.txt
# Скопирован: frame_02323.txt
# Скопирован: frame_02336.txt
# Скопирован: frame_02349.txt
# Скопирован: frame_02362.txt
# Скопирован: frame_02375.txt
# Скопирован: frame_02388.txt
# Скопирован: frame_02401.txt
# Скопирован: frame_02414.txt
# Скопирован: frame_02427.txt
# Скопирован: frame_02440.txt
# Скопирован: frame_02453.txt
# Скопирован: frame_02466.txt
# Скопирован: frame_02479.txt
# Скопирован: frame_02492.txt
# Скопирован: frame_02505.txt
# Скопирован: frame_02518.txt
# Скопирован: frame_02531.txt
# Скопирован: frame_02544.txt
# Скопирован: frame_02557.txt
# Скопирован: frame_02570.txt
# Скопирован: frame_02583.txt
# Скопирован: frame_02596.txt
# Скопирован: frame_02609.txt
# Скопирован: frame_02622.txt
# Скопирован: frame_02635.txt
# Скопирован: frame_02648.txt
# Скопирован: frame_02661.txt
# Скопирован: frame_02674.txt
# Скопирован: frame_02687.txt
# Скопирован: frame_02700.txt
# Скопирован: frame_02713.txt
# Скопирован: frame_02726.txt
# Скопирован: frame_02739.txt
# Скопирован: frame_02752.txt
# Скопирован: frame_02765.txt
# Скопирован: frame_02778.txt
# Скопирован: frame_02791.txt
# Скопирован: frame_02804.txt
# Скопирован: frame_02817.txt
# Скопирован: frame_02830.txt
# Скопирован: frame_02843.txt
# Скопирован: frame_02856.txt
# Скопирован: frame_02869.txt
# Скопирован: frame_02882.txt
# Скопирован: frame_02895.txt
# Скопирован: frame_02908.txt
# Скопирован: frame_02921.txt
# Скопирован: frame_02934.txt
# Скопирован: frame_02947.txt
# Скопирован: frame_02960.txt
# Скопирован: frame_02973.txt
# Скопирован: frame_02986.txt
# Скопирован: frame_02999.txt
# Скопирован: frame_03012.txt
# Скопирован: frame_03025.txt
# Скопирован: frame_03038.txt
# Скопирован: frame_03051.txt
# Скопирован: frame_03064.txt
# Скопирован: frame_03077.txt
# Скопирован: frame_03090.txt
# Скопирован: frame_03103.txt
# Скопирован: frame_03116.txt
# Скопирован: frame_03129.txt
# Скопирован: frame_03142.txt
# Скопирован: frame_03155.txt
# Скопирован: frame_03168.txt
# Скопирован: frame_03181.txt
# Скопирован: frame_03194.txt
# Скопирован: frame_03207.txt
# Скопирован: frame_03220.txt
# Скопирован: frame_03233.txt
# Скопирован: frame_03246.txt
# Скопирован: frame_03259.txt
# Скопирован: frame_03272.txt
# Скопирован: frame_03285.txt
# Скопирован: frame_03298.txt
# Скопирован: frame_03311.txt
# Скопирован: frame_03324.txt
# Скопирован: frame_03337.txt
# Скопирован: frame_03350.txt
# Скопирован: frame_03363.txt
# Скопирован: frame_03376.txt
# Скопирован: frame_03389.txt
# Скопирован: frame_03402.txt
# Скопирован: frame_03415.txt
# Скопирован: frame_03428.txt
# Скопирован: frame_03441.txt
# Скопирован: frame_03454.txt
# Скопирован: frame_03467.txt
# Скопирован: frame_03480.txt
# Скопирован: frame_03493.txt
# Скопирован: frame_03506.txt
# Скопирован: frame_03519.txt
# Скопирован: frame_03532.txt
# Скопирован: frame_03545.txt
# Скопирован: frame_03558.txt
# Скопирован: frame_04806.txt
# Скопирован: frame_04819.txt
# Скопирован: frame_04832.txt
# Скопирован: frame_04845.txt
# Скопирован: frame_04858.txt
# Скопирован: frame_04871.txt
# Скопирован: frame_04884.txt
# Скопирован: frame_04897.txt
# Скопирован: frame_04910.txt
# Скопирован: frame_04923.txt
# Скопирован: frame_04936.txt
# Скопирован: frame_04949.txt
# Скопирован: frame_04962.txt
# Скопирован: frame_04975.txt
# Скопирован: frame_04988.txt
# Скопирован: frame_05001.txt
# Скопирован: frame_05014.txt
# Скопирован: frame_05027.txt
# Скопирован: frame_05040.txt
# Скопирован: frame_05053.txt
# Скопирован: frame_05066.txt
# Скопирован: frame_05079.txt
# Скопирован: frame_05092.txt
# Скопирован: frame_05105.txt
# Скопирован: frame_05118.txt
# Скопирован: frame_05131.txt
# Скопирован: frame_05144.txt
# Скопирован: frame_05157.txt
# Скопирован: frame_05170.txt
# Скопирован: frame_05183.txt
# Скопирован: frame_05196.txt
# Скопирован: frame_05209.txt
# Скопирован: frame_05222.txt
# Скопирован: frame_05235.txt
# Скопирован: frame_05248.txt
# Скопирован: frame_05261.txt
# Скопирован: frame_05274.txt
# Скопирован: frame_05287.txt
# Скопирован: frame_05300.txt
# Скопирован: frame_05313.txt
# Скопирован: frame_05326.txt
# Скопирован: frame_05339.txt
# Скопирован: frame_05352.txt
# Скопирован: frame_05365.txt
# Скопирован: frame_05378.txt
# Скопирован: frame_05391.txt
# Скопирован: frame_05404.txt
# Скопирован: frame_05417.txt
# Скопирован: frame_05430.txt
# Скопирован: frame_05443.txt
# Скопирован: frame_05456.txt
# Скопирован: frame_05469.txt
# Скопирован: frame_05482.txt
# Скопирован: frame_05495.txt
# Скопирован: frame_05508.txt
# Скопирован: frame_05521.txt
# Скопирован: frame_05534.txt
# Скопирован: frame_05547.txt
# Скопирован: frame_05560.txt
# Скопирован: frame_05573.txt
# Скопирован: frame_05586.txt
# Скопирован: frame_05599.txt
# Скопирован: frame_05612.txt
# Скопирован: frame_05625.txt
# Скопирован: frame_05638.txt
# Скопирован: frame_05651.txt
# Скопирован: frame_05664.txt
# Скопирован: frame_05677.txt
# Скопирован: frame_05690.txt
# Скопирован: frame_05703.txt
# Скопирован: frame_05716.txt
# Скопирован: frame_05729.txt
# Скопирован: frame_05742.txt
# Скопирован: frame_05755.txt
# Скопирован: frame_05768.txt
# Скопирован: frame_05781.txt
# Скопирован: frame_05794.txt
# Скопирован: frame_05807.txt
# Скопирован: frame_05820.txt
# Скопирован: frame_05833.txt
# Скопирован: frame_05846.txt
# Скопирован: frame_05859.txt
# Скопирован: frame_05872.txt
# Скопирован: frame_05885.txt
# Скопирован: frame_05898.txt
# Скопирован: frame_05911.txt
# Скопирован: frame_05924.txt
# Скопирован: frame_05937.txt
# Скопирован: frame_05950.txt
# Скопирован: frame_05963.txt
# Скопирован: frame_05976.txt
# Скопирован: frame_05989.txt
# Скопирован: frame_06002.txt
# Скопирован: frame_06015.txt
# Скопирован: frame_06028.txt
# Скопирован: frame_06041.txt
# Скопирован: frame_06054.txt
# Скопирован: frame_06067.txt
# Скопирован: frame_06080.txt
# Скопирован: frame_06093.txt
# Скопирован: frame_06106.txt
# Скопирован: frame_06119.txt
# Скопирован: frame_06132.txt
# Скопирован: frame_06145.txt
# Скопирован: frame_06158.txt
# Скопирован: frame_06171.txt
# Скопирован: frame_06184.txt
# Скопирован: frame_06197.txt
# Скопирован: frame_06210.txt
# Скопирован: frame_06223.txt
# Скопирован: frame_06236.txt
# Скопирован: frame_06249.txt
# Скопирован: frame_06262.txt
# Скопирован: frame_06275.txt
# Скопирован: frame_06288.txt
# Скопирован: frame_06301.txt
# Скопирован: frame_06314.txt
# Скопирован: frame_06327.txt
# Скопирован: frame_06340.txt
# Скопирован: frame_06353.txt
# Скопирован: frame_06366.txt
# Скопирован: frame_06379.txt
# Скопирован: frame_06392.txt
# Скопирован: frame_06405.txt
# Скопирован: frame_06418.txt
# Скопирован: frame_06431.txt
# Скопирован: frame_06444.txt
# Скопирован: frame_06457.txt
# Скопирован: frame_06470.txt
# Скопирован: frame_06483.txt
# Скопирован: frame_06496.txt
# Скопирован: frame_06509.txt
# Скопирован: frame_06522.txt
# Скопирован: frame_06535.txt
# Скопирован: frame_06548.txt
# Скопирован: frame_06561.txt
# Скопирован: frame_06574.txt
# Скопирован: frame_06587.txt
# Скопирован: frame_06600.txt
# Скопирован: frame_06613.txt
# Скопирован: frame_06626.txt
# Скопирован: frame_06639.txt
# Скопирован: frame_06652.txt
# Скопирован: frame_06665.txt
# Скопирован: frame_06678.txt
# Скопирован: frame_06691.txt
# Скопирован: frame_06704.txt
# Скопирован: frame_06717.txt
# Скопирован: frame_06730.txt
# Скопирован: frame_06743.txt
# Скопирован: frame_06756.txt
# Скопирован: frame_06769.txt
# Скопирован: frame_06782.txt
# Скопирован: frame_06795.txt
# Скопирован: frame_06808.txt
# Скопирован: frame_06821.txt
# Скопирован: frame_06834.txt
# Скопирован: frame_06847.txt
# Скопирован: frame_06860.txt
# Скопирован: frame_06873.txt
# Скопирован: frame_06886.txt
# Скопирован: frame_06899.txt
# Скопирован: frame_06912.txt
# Скопирован: frame_06925.txt
# Скопирован: frame_06938.txt
# Скопирован: frame_06951.txt
# Скопирован: frame_06964.txt
# Скопирован: frame_06977.txt
# Скопирован: frame_06990.txt
# Скопирован: frame_07003.txt
# Скопирован: frame_07016.txt
# Скопирован: frame_07029.txt
# Скопирован: frame_07042.txt
# Скопирован: frame_07055.txt
# Скопирован: frame_07068.txt
# Скопирован: frame_07081.txt
# Скопирован: frame_07094.txt
# Скопирован: frame_07107.txt
# Скопирован: frame_07120.txt
# Скопирован: frame_07133.txt
# Скопирован: frame_07146.txt
# Скопирован: frame_07159.txt
# Скопирован: frame_07172.txt
# Скопирован: frame_07185.txt
# Скопирован: frame_07198.txt
# Скопирован: frame_07211.txt
# Скопирован: frame_07224.txt
# Скопирован: frame_07237.txt
# Скопирован: frame_07250.txt
# Скопирован: frame_07263.txt
# Скопирован: frame_07276.txt
# Скопирован: frame_10579.txt
# Скопирован: frame_10592.txt
# Скопирован: frame_10605.txt
# Скопирован: frame_10618.txt
# Скопирован: frame_10631.txt
# Скопирован: frame_10644.txt
# Скопирован: frame_10657.txt
# Скопирован: frame_10670.txt
# Скопирован: frame_10683.txt
# Скопирован: frame_10696.txt
# Скопирован: frame_10709.txt
# Скопирован: frame_10722.txt
# Скопирован: frame_10735.txt
# Скопирован: frame_10748.txt
# Скопирован: frame_10761.txt
# Скопирован: frame_10774.txt
# Скопирован: frame_10787.txt
# Скопирован: frame_10800.txt
# Скопирован: frame_10813.txt
# Скопирован: frame_10826.txt
# Скопирован: frame_10839.txt
# Скопирован: frame_10852.txt
# Скопирован: frame_10865.txt
# Скопирован: frame_10878.txt
# Скопирован: frame_10891.txt
# Скопирован: frame_10904.txt
# Скопирован: frame_10917.txt
# Скопирован: frame_10930.txt
# Скопирован: frame_10943.txt
# Скопирован: frame_10956.txt
# Скопирован: frame_10969.txt
# Скопирован: frame_10982.txt
# Скопирован: frame_10995.txt
# Скопирован: frame_11008.txt
# Скопирован: frame_11021.txt
# Скопирован: frame_11034.txt
# Скопирован: frame_11047.txt
# Скопирован: frame_11060.txt
# Скопирован: frame_11073.txt
# Скопирован: frame_11086.txt
# Скопирован: frame_11099.txt
# Скопирован: frame_11112.txt
# Скопирован: frame_11125.txt
# Скопирован: frame_11138.txt
# Скопирован: frame_11151.txt
# Скопирован: frame_11164.txt
# Скопирован: frame_11177.txt
# Скопирован: frame_11190.txt
# Скопирован: frame_11203.txt
# Скопирован: frame_11216.txt
# Скопирован: frame_11229.txt
# Скопирован: frame_11242.txt
# Скопирован: frame_11255.txt
# Скопирован: frame_11268.txt
# Скопирован: frame_11281.txt
# Скопирован: frame_11294.txt
# Скопирован: frame_11307.txt
# Скопирован: frame_11320.txt
# Скопирован: frame_11333.txt
# Скопирован: frame_11346.txt
# Скопирован: frame_11359.txt
# Скопирован: frame_11372.txt
# Скопирован: frame_11385.txt
# Скопирован: frame_11398.txt
# Скопирован: frame_11411.txt
# Скопирован: frame_11424.txt
# Скопирован: frame_11437.txt
# Скопирован: frame_11450.txt
# Скопирован: frame_11463.txt
# Скопирован: frame_11476.txt
# Скопирован: frame_11489.txt
# Скопирован: frame_11502.txt
# Скопирован: frame_11515.txt
# Скопирован: frame_11528.txt
# Скопирован: frame_11541.txt
# Скопирован: frame_11554.txt
# Скопирован: frame_11567.txt
# Скопирован: frame_11580.txt
# Скопирован: frame_11593.txt
# Скопирован: frame_11606.txt
# Скопирован: frame_11619.txt
# Скопирован: frame_11632.txt
# Скопирован: frame_11645.txt
# Скопирован: frame_11658.txt
# Скопирован: frame_11671.txt
# Скопирован: frame_11684.txt
# Скопирован: frame_11697.txt
# Скопирован: frame_11710.txt
# Скопирован: frame_11723.txt
# Скопирован: frame_11736.txt
# Скопирован: frame_11749.txt
# Скопирован: frame_11762.txt
# Скопирован: frame_11775.txt
# Скопирован: frame_11788.txt
# Скопирован: frame_11801.txt
# Скопирован: frame_13049.txt
# Скопирован: frame_13062.txt
# Скопирован: frame_13075.txt
# Скопирован: frame_13088.txt
# Скопирован: frame_13101.txt
# Скопирован: frame_13114.txt
# Скопирован: frame_13127.txt
# Скопирован: frame_13140.txt
# Скопирован: frame_13153.txt
# Скопирован: frame_13166.txt
# Скопирован: frame_13179.txt
# Скопирован: frame_13192.txt
# Скопирован: frame_13205.txt
# Скопирован: frame_13218.txt
# Скопирован: frame_13231.txt
# Скопирован: frame_13244.txt
# Скопирован: frame_13257.txt
# Скопирован: frame_13270.txt
# Скопирован: frame_13283.txt
# Скопирован: frame_13296.txt
# Скопирован: frame_13309.txt
# Скопирован: frame_13322.txt
# Скопирован: frame_13335.txt
# Скопирован: frame_13348.txt
# Скопирован: frame_13361.txt
# Скопирован: frame_13374.txt
# Скопирован: frame_13387.txt
# Скопирован: frame_13400.txt
# Скопирован: frame_13413.txt
# Скопирован: frame_13426.txt
# Скопирован: frame_13439.txt
# Скопирован: frame_13452.txt
# Скопирован: frame_13465.txt
# Скопирован: frame_13478.txt
# Скопирован: frame_13491.txt
# Скопирован: frame_13504.txt
# Скопирован: frame_13517.txt
# Скопирован: frame_13530.txt
# Скопирован: frame_13543.txt
# Скопирован: frame_13556.txt
# Скопирован: frame_13569.txt
# Скопирован: frame_13582.txt
# Скопирован: frame_13595.txt
# Скопирован: frame_13608.txt
# Скопирован: frame_13621.txt
# Скопирован: frame_13634.txt
# Скопирован: frame_13647.txt
# Скопирован: frame_13660.txt
# Скопирован: frame_13673.txt
# Скопирован: frame_13686.txt
# Скопирован: frame_13699.txt
# Скопирован: frame_13712.txt
# Скопирован: frame_13725.txt
# Скопирован: frame_13738.txt
# Скопирован: frame_13751.txt
# Скопирован: frame_13764.txt
# Скопирован: frame_13777.txt
# Скопирован: frame_13790.txt
# Скопирован: frame_13803.txt
# Скопирован: frame_13816.txt
# Скопирован: frame_13829.txt
# Скопирован: frame_13842.txt
# Скопирован: frame_13855.txt
# Скопирован: frame_13868.txt
# Скопирован: frame_13881.txt
# Скопирован: frame_13894.txt
# Скопирован: frame_13907.txt
# Скопирован: frame_13920.txt
# Скопирован: frame_13933.txt
# Скопирован: frame_13946.txt
# Скопирован: frame_13959.txt
# Скопирован: frame_13972.txt
# Скопирован: frame_13985.txt
# Скопирован: frame_13998.txt
# Скопирован: frame_14011.txt
# Скопирован: frame_14024.txt
# Скопирован: frame_14037.txt
# Скопирован: frame_14050.txt
# Скопирован: frame_14063.txt
# Скопирован: frame_14076.txt
# Скопирован: frame_14089.txt
# Скопирован: frame_14102.txt
# Скопирован: frame_14115.txt
# Скопирован: frame_14128.txt
# Скопирован: frame_14141.txt
# Скопирован: frame_14154.txt
# Скопирован: frame_14167.txt
# Скопирован: frame_14180.txt
# Скопирован: frame_14193.txt
# Скопирован: frame_14206.txt
# Скопирован: frame_14219.txt
# Скопирован: frame_14232.txt
# Скопирован: frame_14245.txt
# Скопирован: frame_14258.txt
# Скопирован: frame_14271.txt
# Скопирован: frame_14284.txt
# Скопирован: frame_14297.txt
# Скопирован: frame_14310.txt
# Скопирован: frame_14323.txt
# Скопирован: frame_14336.txt
# Скопирован: frame_14349.txt
# Скопирован: frame_14362.txt
# Скопирован: frame_14375.txt
# Скопирован: frame_14388.txt
# Скопирован: frame_14401.txt
# Скопирован: frame_14414.txt
# Скопирован: frame_14427.txt
# Скопирован: frame_14440.txt
# Скопирован: frame_14453.txt
# Скопирован: frame_14466.txt
# Скопирован: frame_14479.txt
# Скопирован: frame_14492.txt
# Скопирован: frame_14505.txt
# Скопирован: frame_14518.txt
# Скопирован: frame_14531.txt
# Скопирован: frame_14544.txt
# Скопирован: frame_14557.txt
# Скопирован: frame_14570.txt
# Скопирован: frame_14583.txt
# Скопирован: frame_14596.txt
# Скопирован: frame_14609.txt
# Скопирован: frame_14622.txt
# Скопирован: frame_14635.txt
# Скопирован: frame_14648.txt
# Скопирован: frame_14661.txt
# Скопирован: frame_14674.txt
# Скопирован: frame_14687.txt
# Скопирован: frame_14700.txt
# Скопирован: frame_14713.txt
# Скопирован: frame_14726.txt
# Скопирован: frame_14739.txt
# Скопирован: frame_14752.txt
# Скопирован: frame_14765.txt
# Скопирован: frame_14778.txt
# Скопирован: frame_14791.txt
# Скопирован: frame_14804.txt
# Скопирован: frame_14817.txt
# Скопирован: frame_14830.txt
# Скопирован: frame_14843.txt
# Скопирован: frame_14856.txt
# Скопирован: frame_14869.txt
# Скопирован: frame_14882.txt
# Скопирован: frame_14895.txt
# Скопирован: frame_14908.txt
# Скопирован: frame_14921.txt
# Скопирован: frame_14934.txt
# Скопирован: frame_14947.txt
# Скопирован: frame_14960.txt
# Скопирован: frame_14973.txt
# Скопирован: frame_14986.txt
# Скопирован: frame_14999.txt
# Скопирован: frame_15012.txt
# Скопирован: frame_15025.txt
# Скопирован: frame_15038.txt
# Скопирован: frame_15051.txt
# Скопирован: frame_15064.txt
# Скопирован: frame_15077.txt
# Скопирован: frame_15090.txt
# Скопирован: frame_15103.txt
# Скопирован: frame_15116.txt
# Скопирован: frame_15129.txt
# Скопирован: frame_15142.txt
# Скопирован: frame_15155.txt
# Скопирован: frame_15168.txt
# Скопирован: frame_15181.txt
# Скопирован: frame_15194.txt
# Скопирован: frame_15207.txt
# Скопирован: frame_15220.txt
# Скопирован: frame_15233.txt
# Скопирован: frame_15246.txt
# Скопирован: frame_15259.txt
# Скопирован: frame_15272.txt
# Скопирован: frame_15285.txt
# Скопирован: frame_15298.txt
# Скопирован: frame_15311.txt
# Скопирован: frame_15324.txt
# Скопирован: frame_15337.txt
# Скопирован: frame_15350.txt
# Скопирован: frame_15363.txt
# Скопирован: frame_15376.txt
# Скопирован: frame_15389.txt
# Скопирован: frame_15402.txt
# Скопирован: frame_15415.txt
# Скопирован: frame_15428.txt
# Скопирован: frame_15441.txt
# Скопирован: frame_15454.txt
# Скопирован: frame_15467.txt
# Скопирован: frame_15480.txt
# Скопирован: frame_15493.txt
# Скопирован: frame_15506.txt
# Скопирован: frame_15519.txt
# Скопирован: frame_15532.txt
# Скопирован: frame_15545.txt
# Скопирован: frame_15558.txt
# Скопирован: frame_15571.txt
# Скопирован: frame_15584.txt
# Скопирован: frame_15597.txt
# Скопирован: frame_15610.txt
# Скопирован: frame_15623.txt
# Скопирован: frame_16026.txt
# Скопирован: frame_16039.txt
# Скопирован: frame_16052.txt
# Скопирован: frame_16065.txt
# Скопирован: frame_16078.txt
# Скопирован: frame_16091.txt
# Скопирован: frame_16104.txt
# Скопирован: frame_16117.txt
# Скопирован: frame_16130.txt
# Скопирован: frame_16143.txt
# Скопирован: frame_16156.txt
# Скопирован: frame_16169.txt
# Скопирован: frame_16182.txt
# Скопирован: frame_16195.txt
# Скопирован: frame_16208.txt
# Скопирован: frame_16221.txt
# Скопирован: frame_16234.txt
# Скопирован: frame_16247.txt
# Скопирован: frame_16260.txt
# Скопирован: frame_16273.txt
# Скопирован: frame_16286.txt
# Скопирован: frame_16299.txt
# Скопирован: frame_16312.txt
# Скопирован: frame_16325.txt
# Скопирован: frame_16338.txt
# Скопирован: frame_16351.txt
# Скопирован: frame_16364.txt
# Скопирован: frame_16377.txt
# Скопирован: frame_16390.txt
# Скопирован: frame_16403.txt
# Скопирован: frame_16416.txt
# Скопирован: frame_16429.txt
# Скопирован: frame_16442.txt
# Скопирован: frame_16455.txt
# Скопирован: frame_16468.txt
# Скопирован: frame_16481.txt
# Скопирован: frame_16494.txt
# Скопирован: frame_16507.txt
# Скопирован: frame_16520.txt
# Скопирован: frame_16533.txt
# Скопирован: frame_16546.txt
# Скопирован: frame_16559.txt
# Скопирован: frame_16572.txt
# Скопирован: frame_16585.txt
# Скопирован: frame_16598.txt
# Скопирован: frame_16611.txt
# Скопирован: frame_16624.txt
# Скопирован: frame_16637.txt
# Скопирован: frame_16650.txt
# Скопирован: frame_16663.txt
# Скопирован: frame_16676.txt
# Скопирован: frame_16689.txt
# Скопирован: frame_16702.txt
# Скопирован: frame_16715.txt
# Скопирован: frame_16728.txt
# Скопирован: frame_16741.txt
# Скопирован: frame_16754.txt
# Скопирован: frame_16767.txt
# Скопирован: frame_16780.txt
# Скопирован: frame_16793.txt
# Скопирован: frame_16806.txt
# Скопирован: frame_16819.txt
# Скопирован: frame_16832.txt
# Скопирован: frame_16845.txt
# Скопирован: frame_16858.txt
# Скопирован: frame_16871.txt
# Скопирован: frame_16884.txt
# Скопирован: frame_16897.txt
# Скопирован: frame_16910.txt
# Скопирован: frame_16923.txt
# Скопирован: frame_16936.txt
# Скопирован: frame_16949.txt
# Скопирован: frame_16962.txt
# Скопирован: frame_16975.txt
# Скопирован: frame_16988.txt
# Скопирован: frame_17001.txt
# Скопирован: frame_17014.txt
# Скопирован: frame_17027.txt
# Скопирован: frame_17040.txt
# Скопирован: frame_17053.txt
# Скопирован: frame_17066.txt
# Скопирован: frame_17079.txt
# Скопирован: frame_17092.txt
# Скопирован: frame_17105.txt
# Скопирован: frame_17118.txt
# Скопирован: frame_17131.txt
# Скопирован: frame_17144.txt
# Скопирован: frame_17157.txt
# Скопирован: frame_17170.txt
# Скопирован: frame_17183.txt
# Скопирован: frame_17196.txt

# %%
from ultralytics.models import YOLO

model = YOLO("yolo11s.pt")  # или "yolov8s.pt"
model.train(
    data=".\data\config.yaml",
    epochs=2,
    imgsz=640,
    batch=4,
    workers=0,
    amp=False,
    device="cpu",
    project="runs",
    name="y11s_custom",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.204 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.11.9 torch-2.7.1+cpu CPU (AMD Ryzen 5 4600H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=False, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=.\data\config.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=2, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=y11s_custom9, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Projects\Eve-Online-Mining-Bot\Find interface elements\runs\y11s_custom9, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    821730  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,430,114 parameters, 9,430,098 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.1 ms, read: 57.026.2 MB/s, size: 598.7 KB)
# train: Scanning D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01\labels\train... 10937 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10937/10937 359.4it/s 30.4s<0.0s
# train: New cache created: D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 229.1241.4 MB/s, size: 494.1 KB)
# val: Scanning D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01\labels\val... 1169 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1169/1169 427.3it/s 2.7s0.1s
# val: New cache created: D:\Projects\Eve-Online-Mining-Bot\Find interface elements\data\mining_asteroid_01\labels\val.cache
# Plotting labels to D:\Projects\Eve-Online-Mining-Bot\Find interface elements\runs\y11s_custom9\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\Projects\Eve-Online-Mining-Bot\Find interface elements\runs\y11s_custom9
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2         0G      2.065      4.704      1.661         90        640: 0% ──────────── 4/2735 0.2it/s 17.7s<3:24:59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from ultralytics.models import YOLO
#       2 model = YOLO("yolo11s.pt")          # или "yolov8s.pt"
# ----> 3 model.train(data=".\data\config.yaml",
#       4             epochs=2, imgsz=640, batch=4, workers=0, amp=False, device="cpu", project="runs", name="y11s_custom")
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\ultralytics\engine\trainer.py:231, in BaseTrainer.train(self)
#     228         ddp_cleanup(self, str(file))
#     230 else:
# --> 231     self._do_train(world_size)
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\ultralytics\engine\trainer.py:426, in BaseTrainer._do_train(self, world_size)
#     421     self.tloss = (
#     422         (self.tloss * i + self.loss_items) / (i + 1) if self.tloss is not None else self.loss_items
#     423     )
#     425 # Backward
# --> 426 self.scaler.scale(self.loss).backward()
#     428 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     429 if ni - last_opt_step >= self.accumulate:
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\torch\_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\torch\autograd\__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File c:\Users\Kurosovaya\AppData\Local\pypoetry\Cache\virtualenvs\ml-global-LpYHm-9p-py3.11\Lib\site-packages\torch\autograd\graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
from ultralytics.models import YOLO
from PIL import Image
from pathlib import Path
import os
from matplotlib import pyplot as plt

os.chdir("../../")

model = YOLO(
    r"D:\\Projects\\my_ml_backend\\models\\RectangleLabelsObbModel\\weights\\best.pt"
)
res = model.predict(
    source=r"D:\Datasets\EVE-images/2025-09-17_17-13-08/pred/images/2025-09-17_17-13-08_0000001076.jpg",
    imgsz=1280,
    rect=True,
    conf=0.25,
)

r = res[0]
im_bgr = r.plot()  # аннотированное изображение в BGR (np.ndarray)
im_rgb = im_bgr[..., ::-1]  # в RGB для matplotlib

plt.imshow(im_rgb)
plt.axis("off")
plt.show()
# Out:
# image 1/1 D:\Datasets\EVE-images\2025-09-17_17-13-08\pred\images\2025-09-17_17-13-08_0000001076.jpg: 800x1280 1 UI: Bookmarks, 2 UI: Sidebars, 1 UI: Station infopanel, 1 UI: Warehouse, 360.9ms
# Speed: 95.2ms preprocess, 360.9ms inference, 25.0ms postprocess per image at shape (1, 3, 800, 1280)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import yaml

with open("..\data\config.yaml") as file:
    data = yaml.safe_load(file)

print(data)
# Out:
# {'path': '/kaggle/input/', 'train': ['eve-mining-asteroid/mining_asteroid_01/images/train', 'eve-ui-and-text/ui_01/images/train'], 'val': ['eve-mining-asteroid/mining_asteroid_01/images/val', 'eve-ui-and-text/ui_01/images/val'], 'names': {0: 'Text', 1: 'UI', 2: 'Asteroid', 3: 'My ship', 4: 'Ship', 5: 'Planet'}}

# %%
import os, re, time, hashlib, mimetypes, pathlib
import requests

API_KEY = os.getenv("GOOGLE_API_KEY") or "YOUR_API_KEY"
CX = os.getenv("GOOGLE_CX") or "YOUR_CX"  # ID Programmable Search Engine
QUERY = "EVE Online UI icons"  # твой запрос
N = 200  # сколько изображений хотим
OUTDIR = "downloads_eve_images"

os.makedirs(OUTDIR, exist_ok=True)

SESSION = requests.Session()
SESSION.headers.update({"User-Agent": "img-downloader/1.0"})


def sanitize(name: str, maxlen=80):
    name = re.sub(r"[^\w\-_. ]+", "_", name).strip()
    return name[:maxlen] or "img"


def download(url: str, outdir: str, hint_title: str = ""):
    try:
        r = SESSION.get(url, timeout=15, stream=True)
        r.raise_for_status()
        ctype = r.headers.get("Content-Type", "")
        if not ctype.startswith(("image/", "application/octet-stream")):
            return False, f"skip content-type={ctype}"

        # имя файла по хэшу урла + расширение по mime (если есть)
        h = hashlib.sha1(url.encode("utf-8")).hexdigest()[:12]
        ext = mimetypes.guess_extension(ctype.split(";")[0].strip()) or ""
        title = sanitize(hint_title) if hint_title else h
        fname = f"{title}_{h}{ext}"
        path = os.path.join(outdir, fname)
        with open(path, "wb") as f:
            for chunk in r.iter_content(1 << 15):
                if chunk:
                    f.write(chunk)
        return True, path
    except Exception as e:
        return False, str(e)


def google_image_search(query: str, api_key: str, cx: str, start: int = 1):
    # см. cse.list + searchType=image
    # https://developers.google.com/custom-search/v1/reference/rest/v1/cse/list
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "key": api_key,
        "cx": cx,
        "q": query,
        "searchType": "image",
        "safe": "off",
        "start": start,  # 1..101 (макс 10 страниц * 10)
        "num": 10,  # 1..10
        # опционально: imgType, imgSize, rights, fileType, etc.
    }
    r = SESSION.get(url, params=params, timeout=15)
    r.raise_for_status()
    return r.json()


saved, start = 0, 1
seen_urls = set()

while saved < N and start <= 101:
    data = google_image_search(QUERY, API_KEY, CX, start=start)
    items = data.get("items") or []
    if not items:
        break

    for it in items:
        link = it.get("link")
        title = it.get("title") or ""
        if not link or link in seen_urls:
            continue
        ok, info = download(link, OUTDIR, hint_title=title)
        if ok:
            saved += 1
            print(f"[{saved}/{N}] {info}")
        else:
            print(f"[skip] {link} -> {info}")
        seen_urls.add(link)
        if saved >= N:
            break

    # следующий «пакет» (страница)
    start += 10
    time.sleep(0.3)  # чуть бережнее к лимитам

print(f"Done: saved {saved} files in {OUTDIR}")

# %% [markdown]
# <h1 style="color: #cd36d5ff">Pre-anotation для label-studio</h1>

# %%
from ultralytics.models import YOLO
import json, os, glob

model = YOLO(
    r"D:\Projects\Eve-Online-Mining-Bot/Find interface elements/output_kaggle/results_v2/runs/y11s_custom/weights/best.pt"
)
images = r"D:\Datasets\EVE\mining_asteroid_02\mining_asteroid_01_0000000223.jpg"

results = model.predict(images, conf=0.10, save=False)

tasks = []
for r in results:
    h, w = r.orig_shape  # высота/ширина исходного изображения
    url_or_path = r.path  # подставь сюда URL, если импортируешь по URL
    result_items = []
    for b in r.boxes:
        x1, y1, x2, y2 = b.xyxy[0].tolist()
        cls = int(b.cls[0])
        label = model.names[cls]
        # Переводим в проценты для Label Studio (если используешь local file server/URL)
        value = {
            "x": x1 / w * 100,
            "y": y1 / h * 100,
            "width": (x2 - x1) / w * 100,
            "height": (y2 - y1) / h * 100,
            "rotation": 0,
            "rectanglelabels": [label],
        }
        result_items.append(
            {
                "from_name": "label",
                "to_name": "image",
                "type": "rectanglelabels",
                "value": value,
                "score": float(b.conf[0]),
            }
        )

    tasks.append(
        {"data": {"image": url_or_path}, "predictions": [{"result": result_items}]}
    )

with open("mining_asteroid_02.json", "w", encoding="utf-8") as f:
    json.dump(tasks, f, ensure_ascii=False)
# Out:
# image 1/1 D:\Datasets\EVE\mining_asteroid_02\mining_asteroid_01_0000000223.jpg: 608x960 1 UI, 251.8ms
# Speed: 8.2ms preprocess, 251.8ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 960)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

IMG_PATH = r"D:\Datasets\EVE-images\\2025-09-17_17-18-32\\pred2\\images/2025-09-17_17-18-32_0000001421.jpg"
TPL_PATH = r"D:\Projects\Eve-Online-Mining-Bot\cv_eve\utils\templates\overview panel_4.png"

img = cv.imread(IMG_PATH, cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
img2 = img.copy()

template = cv.imread(TPL_PATH, cv.IMREAD_GRAYSCALE)
assert template is not None, "file could not be read, check with os.path.exists()"
w, h = template.shape[::-1]

methods = [
    "TM_CCOEFF_NORMED"
]

def score_to_percent(method, min_val, max_val):
    """
    Returns (best_score, percent or None, best_is_min)
    - For *_NORMED:
        * SQDIFF_NORMED: best is min (0 is perfect) -> percent = (1 - best)*100
        * others: best is max (1 is perfect) -> percent = best*100
    - For non-normed: percent=None (score scale isn't bounded)
    """
    is_normed = method.endswith("_NORMED")
    if not is_normed:
        # no honest percent here
        if method in ("TM_SQDIFF",):
            return min_val, None, True
        return max_val, None, False

    if method == "TM_SQDIFF_NORMED":
        best = min_val
        percent = (1.0 - best) * 100.0
        return best, percent, True
    else:
        best = max_val
        percent = best * 100.0
        return best, percent, False


for meth in methods:
    img = img2.copy()
    method = getattr(cv, meth)

    res = cv.matchTemplate(img, template, method)
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    best_score, percent, best_is_min = score_to_percent(meth, min_val, max_val)
    top_left = min_loc if best_is_min else max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv.rectangle(img, top_left, bottom_right, 255, 2)

    # Pretty title
    if percent is None:
        title = f"{meth} | score={best_score:.4f} (raw)"
    else:
        title = f"{meth} | match={percent:.2f}% | score={best_score:.4f}"

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(res, cmap="gray")
    plt.title("Matching Result")
    plt.xticks([]), plt.yticks([])

    plt.subplot(1, 2, 2)
    plt.imshow(img, cmap="gray")
    plt.title("Detected Point")
    plt.xticks([]), plt.yticks([])

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()
